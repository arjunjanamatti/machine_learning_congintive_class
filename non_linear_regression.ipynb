# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph
y = 2*(x) + 3
y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise
#plt.figure(figsize=(8,6))
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# ### Cubic function example

# %%
x = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph
y = 1*(x**3) + 1*(x**2) + 1*x + 3
y_noise = 20 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# ### Quadratic function example

# %%
x = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph

y = np.power(x,2)
y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# ### Exponential function example

# %%
X = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph

Y= np.exp(X)

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# ### Logarithmic function example

# %%
X = np.arange(-5.0, 5.0, 0.1)

Y = np.log(X)

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()
# Out:
# C:\Users\Arjun Janamatti\Anaconda3\envs\new\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Sigmoid function example

# %%
X = np.arange(-5.0, 5.0, 0.1)


Y = 1-4/(1+np.power(3, X-2))

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# ### Example

# %%
raw_data = pd.read_csv("china_gdp.csv")
raw_data
# Out:
#     Year         Value
# 0   1960  5.918412e+10
# 1   1961  4.955705e+10
# 2   1962  4.668518e+10
# 3   1963  5.009730e+10
# 4   1964  5.906225e+10
# 5   1965  6.970915e+10
# 6   1966  7.587943e+10
# 7   1967  7.205703e+10
# 8   1968  6.999350e+10
# 9   1969  7.871882e+10
# 10  1970  9.150621e+10
# 11  1971  9.856202e+10
# 12  1972  1.121598e+11
# 13  1973  1.367699e+11
# 14  1974  1.422547e+11
# 15  1975  1.611625e+11
# 16  1976  1.516277e+11
# 17  1977  1.723490e+11
# 18  1978  1.483821e+11
# 19  1979  1.768565e+11
# 20  1980  1.896500e+11
# 21  1981  1.943690e+11
# 22  1982  2.035496e+11
# 23  1983  2.289502e+11
# 24  1984  2.580821e+11
# 25  1985  3.074796e+11
# 26  1986  2.988058e+11
# 27  1987  2.713498e+11
# 28  1988  3.107222e+11
# 29  1989  3.459575e+11
# 30  1990  3.589732e+11
# 31  1991  3.814547e+11
# 32  1992  4.249341e+11
# 33  1993  4.428746e+11
# 34  1994  5.622611e+11
# 35  1995  7.320320e+11
# 36  1996  8.608441e+11
# 37  1997  9.581594e+11
# 38  1998  1.025277e+12
# ...

# %%
plt.figure(figsize=(8,5))
x_data, y_data = (raw_data["Year"].values, raw_data["Value"].values)
plt.plot(x_data, y_data, 'ro')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()

# %%
def sigmoid(x, Beta_1, Beta_2):
     y = 1 / (1 + np.exp(-Beta_1*(x-Beta_2)))
     return y

# %%
beta_1 = 0.10
beta_2 = 1990.0

#logistic function
Y_pred = sigmoid(x_data, beta_1 , beta_2)

#plot initial prediction against datapoints
plt.plot(x_data, Y_pred*15000000000000.)
plt.plot(x_data, y_data, 'ro')

# %%
# Lets normalize our data
xdata =x_data/max(x_data)
ydata =y_data/max(y_data)

# %%
from scipy.optimize import curve_fit
popt, pcov = curve_fit(sigmoid, xdata, ydata)
#print the final parameters
print(" beta_1 = %f, beta_2 = %f" % (popt[0], popt[1]))
# Out:
#  beta_1 = 690.451711, beta_2 = 0.997207

# %%
x = np.linspace(1960, 2015, 55)
x = x/max(x)
plt.figure(figsize=(8,5))
y = sigmoid(x, *popt)
plt.plot(xdata, ydata, 'ro', label='data')
plt.plot(x,y, linewidth=3.0, label='fit')
plt.legend(loc='best')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()

# %%
root_mean_square_value = 1 - (( (np.sum((ydata - y_hat)**2))) / ( (np.sum((ydata - np.mean(ydata))**2))))
print("Rsquare value or the accuracy of the model is: ", np.round(root_mean_square_value,2))
# Out:
# Rsquare value or the accuracy of the model is:  0.97

# %%
def check_star(popt):
    print(np.sort(np.array(popt)))

# %%
list_1 = np.arange(10,1,-1)
check_star(list_1)
# Out:
# [ 2  3  4  5  6  7  8  9 10]

# %%
list_1
# Out:
# array([10,  9,  8,  7,  6,  5,  4,  3,  2])
